# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
# Gráfico de línea
x = [1,2,3,4,5]
y = [2,6,9,4,11]

plt.plot(x,y)

plt.xlabel('Eje x')
plt.ylabel('Eje y')
plt.title('Gráfico de línea')

plt.show()
